# %% [markdown]
# # EDA
#
# Exploratory analysis for the DACON AI Agent action prediction dataset.
#
# ## Planned
# - Load `train.jsonl` and `train_labels.csv`
# - Inspect action distribution
# - Analyze prompt/history/session metadata patterns
# - Save reusable figures to `../results/figures/`
