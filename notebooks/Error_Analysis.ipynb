# %% [markdown]
# # Error Analysis
#
# Notebook for reviewing validation errors and identifying confusion patterns between the 14 action classes.
#
# ## Planned
# - Load validation predictions
# - Build confusion matrix
# - Review high-confidence mistakes
# - Export findings to `../docs/06_Error_Analysis.md`
