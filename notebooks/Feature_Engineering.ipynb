# %% [markdown]
# # Feature Engineering
#
# Notebook for designing and validating features from session metadata, history, and current prompts.
#
# ## Planned
# - Extract metadata features
# - Encode history action sequences
# - Compare text representations
# - Document reusable features in `../docs/07_Feature_Engineering.md`
